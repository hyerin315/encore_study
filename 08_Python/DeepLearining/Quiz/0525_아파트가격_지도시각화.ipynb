# %%
import pandas as pd
import os

# %% [markdown]
# * 2020년 01월 국토부 매매데이터를 읽어온다.

# %%
total = []
for roots, dirs, files in os.walk("./data/apt"):
    for file in files:
        total.append(pd.read_csv(roots + "/" + file,
                  header=[15], encoding='euc-kr', low_memory=False))

# %%
df = pd.concat(total)

# %%
df.shape
# Out:
# (852001, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 852001 entries, 0 to 86446
# Data columns (total 13 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   시군구       852001 non-null  object
#  1   번지        851975 non-null  object
#  2   본번        851990 non-null  object
#  3   부번        851990 non-null  float64
#  4   단지명       852001 non-null  object
#  5   전용면적(㎡)   852001 non-null  float64
#  6   계약년월      852001 non-null  int64
#  7   계약일       852001 non-null  int64
#  8   거래금액(만원)  852001 non-null  object
#  9   층         852001 non-null  int64
#  10  건축년도      852001 non-null  int64
#  11  도로명       852001 non-null  object
#  12  해제사유발생일   38511 non-null   float64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 91.0+ MB

# %%
df.head()
# Out:
#            시군구   번지    본번   부번   단지명  전용면적(㎡)    계약년월  계약일 거래금액(만원)   층  건축년도  \
# 0  강원도 강릉시 견소동  202  0202  0.0  송정한신   43.380  202001    3   12,000  12  1997
# 1  강원도 강릉시 견소동  202  0202  0.0  송정한신   59.800  202001   15   10,000   3  1997
# 2  강원도 강릉시 견소동  202  0202  0.0  송정한신   84.945  202001   18   13,500  11  1997
# 3  강원도 강릉시 견소동  202  0202  0.0  송정한신   59.800  202001   18   10,500  12  1997
# 4  강원도 강릉시 견소동  202  0202  0.0  송정한신  116.175  202001   21   19,000   5  1997
#
#            도로명  해제사유발생일
# 0  경강로2539번길 8      NaN
# 1  경강로2539번길 8      NaN
# 2  경강로2539번길 8      NaN
# 3  경강로2539번길 8      NaN
# 4  경강로2539번길 8      NaN

# %%
df['거래금액(만원)'] = df['거래금액(만원)'].apply(lambda x : int(x.replace(",", "")))

# %%
df.sort_values(by = ['거래금액(만원)'], ascending=False, inplace=True)

# %%
df
# Out:
#                     시군구      번지    본번   부번           단지명  전용면적(㎡)    계약년월  \
# 40134     서울특별시 용산구 한남동     810  0810  0.0          한남더힐  243.642  202009
# 72082     서울특별시 용산구 한남동     810  0810  0.0          한남더힐  241.052  202011
# 40135     서울특별시 용산구 한남동     810  0810  0.0          한남더힐  240.230  202009
# 32175     서울특별시 용산구 한남동     810  0810  0.0          한남더힐  240.305  202004
# 63374     서울특별시 용산구 한남동     810  0810  0.0          한남더힐  240.305  202012
# ...                 ...     ...   ...  ...           ...      ...     ...
# 84438  전라북도 익산시 낭산면 용기리  1150-5  1150  5.0            태양   34.460  202011
# 76901  충청북도 증평군 도안면 석곡리   576-6  0576  6.0  미혼여성근로자임대아파트   37.960  202007
# 76900  충청북도 증평군 도안면 석곡리   576-6  0576  6.0  미혼여성근로자임대아파트   37.960  202007
# 14833     경기도 수원장안구 연무동   226-1  0226  1.0            남창   59.130  202002
# 45119  전라남도 고흥군 도화면 당오리     487  0487  0.0           뉴코아   22.680  202003
#
#        계약일  거래금액(만원)  층  건축년도            도로명  해제사유발생일
# ...

# %% [markdown]
# * 서울의 데이터만 따로 뽑기 위해서 시군구 컬럼에 '서울'이 포함된 row를 선택한다.

# %%
seoul_df = df[df.시군구.str.contains('서울')].copy()

# %%
seoul_df.shape
# Out:
# (83532, 13)

# %% [markdown]
# * 서울 데이터에서 구별로 평균을 계산하기 위해서 '구' 컬럼을 따로 생성

# %%
seoul_df
# Out:
#                  시군구      번지    본번    부번       단지명  전용면적(㎡)    계약년월  계약일  \
# 40134  서울특별시 용산구 한남동     810  0810   0.0      한남더힐  243.642  202009    4
# 72082  서울특별시 용산구 한남동     810  0810   0.0      한남더힐  241.052  202011    9
# 40135  서울특별시 용산구 한남동     810  0810   0.0      한남더힐  240.230  202009   21
# 32175  서울특별시 용산구 한남동     810  0810   0.0      한남더힐  240.305  202004   27
# 63374  서울특별시 용산구 한남동     810  0810   0.0      한남더힐  240.305  202012   31
# ...              ...     ...   ...   ...       ...      ...     ...  ...
# 34648  서울특별시 구로구 오류동   34-13  0034  13.0       썬앤빌   14.064  202003   31
# 52428  서울특별시 구로구 오류동   34-13  0034  13.0       썬앤빌   14.064  202007   21
# 53044  서울특별시 도봉구 쌍문동  357-14  0357  14.0        로얄   42.000  202010   23
# 67750  서울특별시 구로구 개봉동  304-16  0304  16.0        건양   29.340  202011   18
# 74429  서울특별시 구로구 구로동  752-10  0752  10.0  (752-10)   25.530  202006   10
#
#        거래금액(만원)   층  건축년도           도로명  해제사유발생일
# ...

# %%
seoul_df['구'] = seoul_df['시군구'].apply(lambda x : x.split()[1])

# %%
seoul_df.head(5)
# Out:
#                  시군구   번지    본번   부번   단지명  전용면적(㎡)    계약년월  계약일  거래금액(만원)  층  \
# 40134  서울특별시 용산구 한남동  810  0810  0.0  한남더힐  243.642  202009    4    775000  1
# 72082  서울특별시 용산구 한남동  810  0810  0.0  한남더힐  241.052  202011    9    760000 -1
# 40135  서울특별시 용산구 한남동  810  0810  0.0  한남더힐  240.230  202009   21    730000  3
# 32175  서울특별시 용산구 한남동  810  0810  0.0  한남더힐  240.305  202004   27    730000 -1
# 63374  서울특별시 용산구 한남동  810  0810  0.0  한남더힐  240.305  202012   31    710000  2
#
#        건축년도       도로명  해제사유발생일    구
# 40134  2011  독서당로 111      NaN  용산구
# 72082  2011  독서당로 111      NaN  용산구
# 40135  2011  독서당로 111      NaN  용산구
# 32175  2011  독서당로 111      NaN  용산구
# 63374  2011  독서당로 111      NaN  용산구

# %% [markdown]
# * groupby를 계산하고 대상이 index로 이동하는 것을 막기 위해서 as_index 옵션을 False로 설정
# * as_index 값은 기본값으로 True

# %%
seoul_gu = seoul_df.groupby(['구'], as_index=False)['거래금액(만원)'].agg(['mean',
                                                    'max', 'min', 'std'])

# %%
seoul_gu.reset_index(inplace=True)

# %%
seoul_gu
# Out:
#        구           mean     max    min           std
# 0    강남구  180793.334296  670000  15000  95857.318288
# 1    강동구   83895.275214  249000   8000  36894.115216
# 2    강북구   55995.924039  128000   7500  18462.817813
# 3    강서구   67769.541724  162000   7700  26646.292703
# 4    관악구   61873.218365  136000   9000  20990.492035
# 5    광진구  106792.921875  269500   8500  42803.658600
# 6    구로구   54513.885652  170000   6000  25607.255537
# 7    금천구   46959.113811  125000   8000  22214.725826
# 8    노원구   52225.097713  157000   8000  19728.118687
# 9    도봉구   45738.368514  140000   6500  18206.688270
# 10  동대문구   71150.548959  165000   8500  28144.818152
# 11   동작구   97796.615986  290000  12400  31696.478721
# 12   마포구  101331.594440  240000  13300  36852.202912
# 13  서대문구   78501.623668  176000  11000  31778.589972
# 14   서초구  175100.116950  550000  15000  87090.356300
# 15   성동구  114389.284577  670000  12050  47467.009148
# 16   성북구   68732.441661  149000  11500  20816.994439
# ...

# %% [markdown]
# * 지도를 그리기 위한 데이터를 불러 들인다. skorea_municipal... 이 데이터는 서울시 행정구역 위치에 설정한 파일이며
# * 파일의 출처는 https://github.com/southkorea/southkorea-maps/blob/master/kostat/2013/json/skorea_municipalities_geo_simple.json
# * 이 데이터를 읽어서 처리하기 위해서는 folium이라는 패키지가 필요하니 만약 없으면 설치해야 한다.

# %%
import json
import folium
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)
geo_path = './data/skorea_municipalities_geo_simple/skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
geo_str
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': '강동구',
#    'properties': {'code': '11250',
#     'name': '강동구',
#     'name_eng': 'Gangdong-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.11519584981606, 37.557533180704915],
#       [127.16683184366129, 37.57672487388627],
#       [127.18408792330152, 37.55814280369575],
#       [127.16530984307447, 37.54221851258693],
#       [127.14672806823502, 37.51415680680291],
#       [127.12123165719615, 37.52528270089],
#       [127.1116764203608, 37.540669955324965],
#       [127.11519584981606, 37.557533180704915]]]}},
#   {'type': 'Feature',
#    'id': '송파구',
#    'properties': {'code': '11240',
#     'name': '송파구',
#     'name_eng': 'Songpa-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.0690698130372, 37.522279423505026],
#       [127.10087519791962, 37.524841220167055],
# ...

# %% [markdown]
# * 지도위에 서울를 설정한다.

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# * 지도 위에 choropleth 함수에 거래금액을 넘겨 지도위에 색깔을 입힌다.

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')
map.choropleth(geo_data = geo_str,
               data = seoul_gu,
               columns = ['구', 'mean'],
               fill_color = 'PuRd', #PuRd, YlGnBu
               key_on = 'feature.id')
folium.LayerControl().add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# * 해당 결과를 아래 html 파일 형식으로 저장한다.

# %%
map.save("./data/2020_01_map_test.html")
